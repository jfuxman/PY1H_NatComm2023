# %% [markdown]
# Predicting possible TF-TF interactions based on homology

# %%
import xlrd
import itertools
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import requests

# %%
#!python -m wget http://www.interactome-atlas.org/data/HuRI.tsv
#!python -m wget http://humantfs.ccbr.utoronto.ca/download/v_1.01/DatabaseExtract_v_1.01.txt
# !python -m wget http://www.interactome-atlas.org/data/Lit-BM.tsv
# Out:
# Saved under Lit-BM.tsv

# %%
# Function to Parse FASTA
def parse_file(file):
    with open(file, "r") as f1:
        header, seqs = [], []
        for line in f1:
            line = line.rstrip()
            if line.startswith(">"):
                if header: yield(header,''.join(seqs))
                header, seqs = line, []
            else:
                seqs.append(line)
        if header: yield(header,''.join(seqs))

# %%
Lambert = pd.read_csv('DatabaseExtract_v_1.01.txt', delimiter = '\t')[ ['Ensembl ID', 'HGNC symbol', 'DBD', 'Is TF?']]
Lambert = Lambert[ Lambert['Is TF?'] == 'Yes']
Lambert
# Out:
#            Ensembl ID HGNC symbol      DBD Is TF?
# 0     ENSG00000137203      TFAP2A     AP-2    Yes
# 1     ENSG00000008196      TFAP2B     AP-2    Yes
# 2     ENSG00000087510      TFAP2C     AP-2    Yes
# 3     ENSG00000008197      TFAP2D     AP-2    Yes
# 4     ENSG00000116819      TFAP2E     AP-2    Yes
# ...               ...         ...      ...    ...
# 2629  ENSG00000151500       THYN1  Unknown    Yes
# 2644  ENSG00000144747        TMF1  Unknown    Yes
# 2656  ENSG00000197579      TOPORS  Unknown    Yes
# 2698  ENSG00000102804     TSC22D1  Unknown    Yes
# 2745  ENSG00000136936         XPA  Unknown    Yes
#
# [1639 rows x 4 columns]

# %%
LitBM = pd.read_csv('Lit-BM.tsv', sep="\t",    header = None)
LitBM = LitBM.rename(columns = {0: 'ENSG_A', 1:'ENSG_B'})
LitBM = LitBM[ ( LitBM['ENSG_A'].isin(Lambert['Ensembl ID']) ) & ( LitBM['ENSG_B'].isin(Lambert['Ensembl ID']) ) ]
LitBM['GENE_A'] = LitBM['ENSG_A'].map(Lambert.set_index('Ensembl ID')['HGNC symbol'])
LitBM['GENE_B'] = LitBM['ENSG_B'].map(Lambert.set_index('Ensembl ID')['HGNC symbol'])

print(LitBM)
# Out:
#                 ENSG_A           ENSG_B  GENE_A GENE_B
# 0      ENSG00000001167  ENSG00000066136    NFYA   NFYC
# 1      ENSG00000001167  ENSG00000120837    NFYA   NFYB
# 31     ENSG00000029153  ENSG00000134852  ARNTL2  CLOCK
# 79     ENSG00000066136  ENSG00000120837    NFYC   NFYB
# 81     ENSG00000067066  ENSG00000067066   SP100  SP100
# ...                ...              ...     ...    ...
# 13330  ENSG00000084676  ENSG00000143257   NCOA1  NR1I3
# 13360  ENSG00000122691  ENSG00000168610  TWIST1  STAT3
# 13373  ENSG00000105516  ENSG00000175197     DBP  DDIT3
# 13412  ENSG00000168610  ENSG00000168610   STAT3  STAT3
# 13414  ENSG00000132170  ENSG00000204231   PPARG   RXRB
#
# [511 rows x 4 columns]

# %%
LitBM_dict = {}

# Make Dictionary
for TF in LitBM['GENE_A']:
    indexs = [ind for ind, x in enumerate(LitBM['GENE_A']) if x == TF]
    tf_2 = [LitBM['GENE_B'].to_list()[i] for i in indexs]
    LitBM_dict[TF] = tf_2

# Considering HURI all interactions
for k in LitBM_dict.keys():
    for tf_pair in LitBM_dict[k]:
        if tf_pair in LitBM_dict and k not in LitBM_dict[tf_pair]:
            LitBM_dict[tf_pair] = LitBM_dict[tf_pair] + [k]

LitBM_dict
# Out:
# {'NFYA': ['NFYC', 'NFYB', 'ZHX1', 'SRF'],
#  'ARNTL2': ['CLOCK'],
#  'NFYC': ['NFYB', 'MYC', 'ATF6', 'NFYA'],
#  'SP100': ['SP100', 'ARID3A'],
#  'FOSL2': ['JUN'],
#  'RARB': ['RXRG', 'NCOA1'],
#  'ZNF446': ['ZNF397'],
#  'HIF1A': ['ARNTL', 'MAFG', 'ARNT', 'HIF1A'],
#  'ZNF174': ['ZSCAN32'],
#  'CREB3': ['CREB3', 'JUN'],
#  'ZBTB16': ['ZBTB16', 'RARA', 'BCL6', 'ZBTB32'],
#  'VDR': ['RXRG', 'RXRA', 'SMAD3', 'NCOA2', 'VDR', 'NCOA3', 'RXRB', 'NCOA1'],
#  'BCL6': ['BCL6', 'BCL6B', 'ZBTB7A', 'JUN', 'ZBTB16', 'PATZ1'],
#  'TFDP2': ['E2F4', 'E2F1'],
#  'ATF2': ['FOS', 'SMAD4', 'ATF2', 'JUN', 'SMAD3', 'ATF3'],
#  'EPAS1': ['ARNTL', 'ARNT', 'ARNT2', 'EPAS1', 'SMAD3'],
#  'NFE2L2': ['MAFG', 'MAFK', 'MAFF'],
#  'TCF21': ['TCF12', 'TCF4', 'TCF3'],
#  'MXI1': ['MAX'],
#  'MAX': ['MYC',
#   'MXD3',
#   'MAX',
#   'MYCN',
#   'MGA',
#   'SMAD3',
#   'MXI1',
#   'MNT',
#   'MXD1',
#   'MXD4'],
#  'NR1H2': ['RXRG', 'RXRB', 'RXRA'],
#  'RARA': ['RXRG',
#   'RXRB',
#   'HMGA1',
#   'RXRA',
#   'NCOA2',
#   'CLOCK',
#   'NPAS2',
#   'ZBTB16',
#   'SRF',
#   'IRX4',
#   'NCOA1',
#   'NCOA3'],
#  'ARNTL': ['CLOCK', 'NPAS2', 'RORC', 'HIF1A', 'EPAS1', 'AHR'],
#  'MEIS2': ['PBX1'],
#  'NR5A1': ['NR0B1', 'ZNF653', 'SP1', 'SOX9', 'TRERF1'],
#  'SMAD4': ['SMAD3',
#   'SMAD1',
#   'SKI',
#   'ZBTB7A',
#   'FOXH1',
#   'SMAD4',
#   'GATA2',
#   'JUNB',
#   'ATF2',
#   'SMAD5',
#   'SKIL'],
#  'BATF': ['JUNB', 'DDIT3'],
#  'USF1': ['USF1', 'FOSL1', 'TCF3'],
#  'REL': ['RELA'],
#  'FOS': ['JUNB',
#   'JUN',
#   'DDIT3',
#   'FOS',
#   'MAF',
#   'ATF2',
#   'MAZ',
#   'SMAD3',
#   'RUNX2',
#   'STAT1',
#   'JUND',
#   'ATF4',
#   'NCOA1',
#   'MTERF4',
#   'ZNF133'],
#  'JUNB': ['FOSL1', 'SMAD4', 'BATF', 'FOS', 'SMAD3', 'BATF2'],
#  'ESRRA': ['ESRRG', 'NCOA1', 'NCOA3'],
#  'ZNF408': ['ZNF408'],
#  'ESRRG': ['ESRRG', 'ESRRA', 'NCOA1'],
#  'TFDP1': ['E2F4', 'E2F1', 'E2F5'],
#  'MYC': ['ZNF281', 'ZNF121', 'SMAD3', 'NFYC', 'MAX', 'YY1', 'ZBTB17', 'HBP1'],
#  'MBD3': ['MECOM', 'MBD3', 'MBD2'],
#  'MBD1': ['SETDB1'],
#  'SRF': ['ATF6',
#   'RARA',
#   'MYOG',
#   'ELK4',
#   'MYOD1',
#   'TEAD1',
#   'RXRG',
#   'CEBPB',
#   'NFYA',
#   'NCOA1'],
#  'ATF6': ['ATF6', 'NFYC', 'SRF'],
#  'PPARD': ['RXRA', 'NCOA2', 'RXRG', 'STAT3', 'RXRB', 'NCOA1'],
#  'GATA1': ['TAL1', 'ZFPM2', 'FLI1'],
#  'TCF3': ['TAL1',
#   'ASCL1',
#   'LMX1A',
#   'TWIST1',
#   'MYOG',
#   'MYOD1',
#   'MYF5',
#   'LYL1',
#   'TCF21',
#   'BHLHE40',
#   'USF1'],
#  'TAL1': ['TCF4', 'SP1', 'GATA1', 'TCF3', 'TCF12'],
#  'MSX2': ['MSX1'],
#  'ZNF76': ['TBP'],
#  'E2F1': ['TFDP2', 'TFDP1', 'STAT1'],
#  'POU2F1': ['SNAPC4', 'SP1', 'POU2AF1', 'HMGA1'],
#  'IRF5': ['IRF5'],
#  'ASCL1': ['TCF4', 'TCF3', 'MEF2A'],
#  'LMX1A': ['LMX1A', 'TCF3'],
#  'GATA4': ['ZFPM2'],
#  'PGR': ['ESR1', 'KLF9', 'BATF3', 'NCOA1'],
#  'BACH1': ['BACH1', 'MAFG', 'MAFF'],
#  'SPDEF': ['NKX3-1'],
#  'CENPX': ['CENPS'],
#  'MAZ': ['BPTF', 'JUN', 'FOS'],
#  'KDM5B': ['FOXG1', 'PAX9'],
#  'GRHL2': ['GRHL3'],
#  'GRHL3': ['GRHL3', 'GRHL2', 'GRHL1'],
#  'NR5A2': ['CREB1', 'NCOA1'],
#  'TCF12': ['TAL1', 'TCF21'],
#  'MNT': ['MAX', 'MNT', 'MLX'],
#  'TFAP2A': ['SP1', 'RELA', 'TP53'],
#  'SREBF1': ['NR0B1', 'ZBTB7C', 'TWIST2'],
#  'CDC5L': ['CDC5L'],
#  'HSF2': ['PCGF2'],
#  'NR3C1': ['NR3C2', 'NR2F2', 'NCOA2', 'CEBPB', 'TMF1', 'CENPB', 'NCOA1'],
#  'AHR': ['ARNT', 'ARNTL', 'NCOA1'],
#  'NFATC2': ['NFATC2'],
#  'ARNT': ['SIM2', 'HIF1A', 'EPAS1', 'AHR', 'AHRR', 'SIM1', 'NCOA2', 'NCOA1'],
#  'ZNF451': ['AR'],
#  'TFE3': ['E2F3'],
#  'MYBL2': ['E2F3', 'MYBL2'],
#  'SOX6': ['SHOX'],
#  'TBP': ['RXRA', 'SP1', 'TP53', 'POU3F2', 'DRAP1', 'GTF2B', 'ZNF76'],
#  'FOXP2': ['FOXP2'],
#  'POU2AF1': ['POU2F1'],
#  'BCL11A': ['NR2E3', 'NR2F2', 'NR2F1', 'NR2E1'],
#  'AHRR': ['ARNT'],
#  'ESR1': ['NR2F1',
#   'FOXO1',
#   'GATA3',
#   'FOXK2',
#   'POU4F1',
#   'ARID5A',
#   'PRDM2',
#   'POU4F2',
#   'LCOR',
#   'NCOA2',
#   'ESR1',
#   'ESR2',
#   'NCOA3',
#   'PGR',
#   'NCOA1'],
#  'SMAD1': ['SMAD1', 'SMAD4', 'HOXC8', 'AR', 'SMAD3', 'ZEB2'],
#  'HOXC8': ['SMAD1'],
#  'AR': ['SMAD1',
#   'SRY',
#   'LCOR',
#   'NR2C2',
#   'AR',
#   'ZNF451',
#   'SMAD3',
#   'FOXO1',
#   'NR2C1',
#   'JUND',
#   'KAT7',
#   'NCOA2',
#   'NCOA1',
#   'PAX6',
#   'TMF1',
#   'NCOA3'],
#  'SMAD3': ['SMAD1',
#   'SMAD3',
#   'JUNB',
#   'FOS',
#   'JUN',
#   'AR',
#   'ZEB2',
#   'VDR',
#   'ATF2',
#   'EPAS1',
#   'MAX',
#   'SMAD4',
#   'MYC',
#   'SKIL',
#   'SKI',
#   'PIN1',
#   'HIVEP1'],
#  'NR2E1': ['BCL11A'],
#  'MLX': ['MLXIP', 'MLX', 'MXD4', 'MNT', 'MLXIPL', 'MXD1'],
#  'MLXIPL': ['MLX'],
#  'IRX4': ['RARA'],
#  'MXD1': ['MLX', 'MAX'],
#  'HNF4A': ['NR1I2', 'NR2C2'],
#  'FOXO1': ['AR', 'ESR1'],
#  'PPARG': ['HMGA1',
#   'RXRA',
#   'PPARG',
#   'NCOA2',
#   'RELA',
#   'NR0B1',
#   'RXRB',
#   'NCOA1',
#   'KLF5',
#   'NCOA3'],
#  'E2F5': ['TFDP1'],
#  'EGR1': ['CEBPB'],
#  'HOXA5': ['TWIST1'],
#  'RUNX2': ['JUN', 'FOS'],
#  'JUN': ['JUN',
#   'DACH1',
#   'FOSL2',
#   'CREB3',
#   'BCL6',
#   'ATF2',
#   'FOS',
#   'MAZ',
#   'SMAD3',
#   'RUNX2',
#   'HMGA1',
#   'ATF4',
#   'NCOA1',
#   'BATF2',
#   'ETS2',
#   'FOSL1',
#   'DDIT3',
#   'ATF3',
#   'ETS1',
#   'BATF3'],
#  'FOXP3': ['RORA', 'ZFP90', 'IKZF4'],
#  'SPI1': ['GATA2', 'IRF4'],
#  'MEF2A': ['ASCL1'],
#  'STAT1': ['STAT1', 'STAT2', 'IRF9', 'FOS', 'RXRA', 'STAT3', 'E2F1'],
#  'NR2C1': ['AR'],
#  'SOX5': ['SHOX'],
#  'NR4A3': ['SIX3'],
#  'HMGA1': ['JUN', 'POU2F1', 'PA2G4', 'RARA', 'PPARG', 'POU2F2'],
#  'POU2F2': ['HMGA1'],
#  'CEBPE': ['CEBPG', 'DDIT3', 'CEBPA'],
#  'PHF1': ['HIC1'],
#  'MECOM': ['HIC1', 'MBD3'],
#  'JUND': ['AR', 'DDIT3', 'FOS'],
#  'KMT2A': ['KMT2A'],
#  'MSX1': ['MSX1', 'MSX2', 'DLX2'],
#  'MBD2': ['HINFP', 'MBD2', 'MBD3'],
#  'SMAD5': ['SMAD4'],
#  'ZHX1': ['ZHX1', 'ZHX3', 'NFYA'],
#  'NME2': ['NME2'],
#  'TBX5': ['NKX2-5'],
#  'YY1': ['MYC', 'MECP2'],
#  'TP53': ['L3MBTL1',
#   'TOPORS',
#   'E4F1',
#   'CXXC1',
#   'SREBF2',
#   'TP53',
#   'ATF3',
#   'TFAP2A',
#   'TBP',
#   'NCOA2',
#   'NCOA1',
#   'PIN1',
#   'TSC22D1',
#   'NR4A1',
#   'CREB1'],
#  'NFIL3': ['NFIL3'],
#  'ATF4': ['DDIT3', 'CREBZF', 'FOS', 'ATF4', 'ATF3', 'FOSL1', 'JUN'],
#  'RBCK1': ['NR1I2'],
#  'IKZF5': ['IKZF4', 'IKZF1', 'IKZF3'],
#  'BCL11B': ['NR2F1'],
#  'NFKB1': ['HMGA2', 'RELA', 'NFKB1', 'STAT3', 'LYL1', 'RELB', 'NFKB2'],
#  'MAFB': ['MAFB'],
#  'PATZ1': ['BCL6', 'MITF'],
#  'ZHX3': ['ZHX3', 'ZHX2', 'ZHX1'],
#  'SIM1': ['ARNT'],
#  'XBP1': ['XBP1'],
#  'THRB': ['NR2F6', 'RXRA', 'NCOA2', 'NCOA1', 'NCOA3'],
#  'NR1H4': ['RXRA', 'NCOA1'],
#  'SP140': ['PIN1'],
#  'NR2F2': ['NR2F2', 'NR3C1', 'BCL11A', 'NR2F6'],
#  'NR2F6': ['NR2F2', 'THRB'],
#  'NRL': ['FIZ1'],
#  'RXRA': ['RXRA',
#   'VDR',
#   'NR1H2',
#   'RARA',
#   'PPARD',
#   'TBP',
#   'PPARG',
#   'STAT1',
#   'THRB',
#   'NR1H4',
#   'NR1I2',
#   'NCOA2',
#   'RELA',
#   'NCOA1',
#   'NR1H3',
#   'NR4A1',
#   'NR4A2',
#   'NPAS2',
#   'THRA'],
#  'NR1I2': ['RXRA', 'HNF4A', 'RBCK1', 'NCOA1'],
#  'MEOX2': ['PAX3', 'PAX1'],
#  'ZBTB17': ['MYC', 'ZBTB49'],
#  'SATB1': ['TOPORS'],
#  'SKIL': ['SMAD3', 'SMAD4'],
#  'MEF2C': ['MYOD1', 'SP1'],
#  'SKI': ['SMAD3', 'SMAD4', 'GLI2', 'GLI3'],
#  'KAT7': ['AR'],
#  'GRHL1': ['GRHL3'],
#  'HMGA2': ['E4F1', 'PA2G4', 'NFKB1'],
#  'EEA1': ['EEA1'],
#  'POU3F2': ['POU3F2', 'TBP', 'SOX10', 'PAX3'],
#  'DNMT1': ['RUNX1'],
#  'STAT3': ['SP1',
#   'ZNF829',
#   'STAT3',
#   'PPARD',
#   'STAT1',
#   'NFKB1',
#   'NR4A1',
#   'ZNF281',
#   'HESX1',
#   'TWIST1'],
#  'NCOA2': ['AR',
#   'THRB',
#   'ARNT',
#   'RXRA',
#   'PPARA',
#   'TP53',
#   'VDR',
#   'RARA',
#   'PPARD',
#   'NR3C1',
#   'ESR1',
#   'PPARG',
#   'ESR2'],
#  'ETV6': ['FLI1'],
#  'MXD4': ['MAX', 'MLX'],
#  'LYL1': ['NFKB1', 'TCF3'],
#  'RELA': ['RELA', 'ZBTB7A', 'RXRA', 'REL', 'TFAP2A', 'PPARG', 'NFKB1', 'RELB'],
#  'NCOA1': ['PPARD',
#   'PPARA',
#   'HNF4G',
#   'STAT6',
#   'PPARG',
#   'AHR',
#   'NCOA1',
#   'THRA',
#   'THRB',
#   'VDR',
#   'ESRRA',
#   'SRF',
#   'ARNT',
#   'RXRA',
#   'RARA',
#   'NR5A2',
#   'NR1I2',
#   'FOS',
#   'ESR1',
#   'NR3C1',
#   'TP53',
#   'JUN',
#   'AR',
#   'NCOA3',
#   'ESR2',
#   'ESRRG',
#   'NR3C2',
#   'RARG',
#   'NR1I3',
#   'RARB',
#   'PGR',
#   'NR1H4',
#   'NR1H3',
#   'RORA'],
#  'NR1H3': ['NCOA1', 'RXRA'],
#  'RORA': ['NCOA1', 'NR0B1', 'FOXP3'],
#  'IRF1': ['IRF8', 'IRF9'],
#  'GLI2': ['SKI'],
#  'GLI3': ['SKI'],
#  'SREBF2': ['SREBF2', 'TP53', 'SP1'],
#  'IKZF4': ['IKZF1', 'FOXP3', 'IKZF5'],
#  'POU1F1': ['PITX1'],
#  'SOX10': ['SOX10', 'POU3F2', 'PAX3'],
#  'PIN1': ['CPEB1', 'TP53', 'SMAD3', 'SP140', 'NCOA3'],
#  'DR1': ['DRAP1'],
#  'AIRE': ['AIRE'],
#  'BATF2': ['JUN', 'JUNB'],
#  'TERF1': ['TERF1', 'SALL1'],
#  'TSC22D1': ['TP53', 'SETDB1', 'TSC22D1'],
#  'NR4A1': ['TP53', 'RXRA', 'STAT3'],
#  'ERG': ['ETS2'],
#  'ETS2': ['JUN', 'ERG'],
#  'HINFP': ['THAP7', 'MBD2'],
#  'KLF5': ['CEBPG', 'PPARG', 'CEBPB'],
#  'ZHX2': ['ZHX2', 'ZHX3'],
#  'KLF6': ['LCOR'],
#  'CEBPZ': ['NFYB'],
#  'TCF4': ['TCF4', 'TCF21', 'TAL1', 'ASCL1'],
#  'SAFB2': ['SAFB'],
#  'SALL1': ['TERF1'],
#  'HBP1': ['MYC'],
#  'PAX3': ['POU3F2', 'MEOX2', 'SOX10', 'MEOX1'],
#  'PAX6': ['AR'],
#  'SOX9': ['MAF', 'NR5A1'],
#  'HOXB1': ['PBX1'],
#  'PBX1': ['HOXB7', 'MEIS2', 'HOXB1'],
#  'BAZ2A': ['TTF1'],
#  'CDX1': ['CEBPA'],
#  'CEBPA': ['CEBPA', 'CEBPE', 'CDX1'],
#  'NR4A2': ['RXRA'],
#  'TMF1': ['AR', 'NR3C1'],
#  'MEOX1': ['PAX3', 'PAX1'],
#  'TRERF1': ['NR5A1'],
#  'NCOA3': ['ESR2',
#   'PIN1',
#   'RARA',
#   'AR',
#   'NKX2-1',
#   'PPARG',
#   'THRB',
#   'ESRRA',
#   'VDR',
#   'ESR1',
#   'NCOA1'],
#  'DLX2': ['MSX1'],
#  'ZBTB32': ['ZBTB16'],
#  'FOSL1': ['JUN', 'USF1', 'JUNB', 'ATF4'],
#  'LEF1': ['MITF'],
#  'TP63': ['TP63'],
#  'TP73': ['TP73'],
#  'CREB3L1': ['CREB3L1'],
#  'CREBZF': ['CREBZF', 'ATF4'],
#  'STAT2': ['IRF9', 'STAT1'],
#  'MYB': ['MAF'],
#  'ESR2': ['NCOA2', 'ESR1', 'NCOA1', 'NCOA3'],
#  'NPAS2': ['RXRA', 'RARA', 'ARNTL'],
#  'ZNF3': ['ZNF3', 'ZNF212'],
#  'TERF2': ['TERF2'],
#  'CREB1': ['TP53', 'CREB1', 'NR5A2'],
#  'FOXH1': ['FOXG1', 'SMAD4'],
#  'DDIT3': ['DDIT3',
#   'JUN',
#   'BATF',
#   'FOS',
#   'CEBPE',
#   'JUND',
#   'ATF4',
#   'ATF3',
#   'DBP'],
#  'ATF3': ['DDIT3', 'JUN', 'ATF3', 'ATF2', 'TP53', 'ATF4'],
#  'MAFG': ['MAFG', 'HIF1A', 'NFE2L2', 'BACH1', 'NFE2L1'],
#  'RXRG': ['PPARA', 'RARB', 'VDR', 'NR1H2', 'RARA', 'SRF', 'PPARD'],
#  'MTERF4': ['FOS'],
#  'ZNF281': ['STAT3', 'MYC'],
#  'ISL1': ['LHX4'],
#  'THRA': ['RXRA', 'NCOA1'],
#  'STAT5A': ['OLIG1'],
#  'CLOCK': ['RORC', 'NR1D2', 'ARNTL2', 'RARA', 'ARNTL'],
#  'ETS1': ['JUN'],
#  'ZEB2': ['SMAD1', 'SMAD3'],
#  'RELB': ['RELA', 'NFKB1'],
#  'HIVEP1': ['SMAD3'],
#  'NFKB2': ['NFKB1'],
#  'MAFF': ['MAFF', 'NFE2L2', 'BACH1', 'BACH2', 'NFE2L1', 'NFE2L3'],
#  'BACH2': ['MAFF'],
#  'NFE2L1': ['MAFF', 'MAFG'],
#  'ZNF212': ['ZNF212', 'ZNF3'],
#  'MAF': ['MAF', 'FOS', 'SOX9', 'MYB'],
#  'NFE2': ['NFE2'],
#  'BATF3': ['JUN', 'PGR'],
#  'NFE2L3': ['MAFF'],
#  'ZNF133': ['FOS'],
#  'HESX1': ['STAT3'],
#  'SP1': ['SREBF2',
#   'NR5A1',
#   'TAL1',
#   'POU2F1',
#   'TFAP2A',
#   'TBP',
#   'MEF2C',
#   'STAT3'],
#  'BHLHE41': ['BHLHE41'],
#  'TWIST1': ['STAT3', 'TCF3', 'HOXA5'],
#  'DBP': ['DDIT3']}

# %%
tf_list = [i.rstrip() for i in Lambert['HGNC symbol'].to_list()]

# Creating dictionary { TF name: TF sequence}
header_tf = {}
for header, seq in parse_file("mart_export.txt"):
    name = header.split("|")[-1]
    for tf in tf_list:
        if tf == name:
            cond_1 = seq.startswith("M")
            cond_2 = seq[-1] == "*"
            if cond_1 and cond_2:
                if name in header_tf:
                    if len(seq) >= len(header_tf[name]):
                        header_tf[name] = seq
                else:
                    header_tf[name] = seq

# Writting all 1619 TF_name / Sequences to go CLUSTAL OMEGA to align and get Matrix Distance
with open("sequences.fasta", "w") as f1:
    for k,v in header_tf.items():
        f1.write(">" + str(k) + "\n")
        f1.write(str(v[:-1]) + "\n")

# %%
# After submitting fasta file to multiple alignment in CLUSTAL OMEGA

# Open Matrix Distance
data_with_zero = []
data = []
i = 3 # First column: index ; Second column: name TF
matrix_distances = []
matrix_tf = []
with open("pim.txt","r") as f1:
    for line in f1:
        line = line.rstrip().split()
        if "#" not in line and len(line)>0:
            matrix_distances.append(line[2:])
            matrix_tf.append(line[1])
            j = i
            for x in line[j:]:
                if x == '-nan':
                    continue
                elif x == "0.00":
                    data_with_zero.append(float(x))
                else:
                    data.append(float(x))
                    data_with_zero.append(float(x))
            i+=1
percentiles = [0.90, 0.95, 0.975, 0.99, 0.995, 0.999]

import numpy as np

for i in percentiles:
    print(i, np.quantile(data_with_zero,i))

percentiles = [0.90]
# Out:
# 0.9 26.92
# 0.95 38.51
# 0.975 44.03
# 0.99 48.79
# 0.995 51.33
# 0.999 68.83

# %%
# list of TF in LitBM
TF_LitBM = list(set(LitBM['GENE_A'].to_list() + LitBM['GENE_B'].to_list()))

# %%
# Get index of TF LitBM in Matrix_TF:
index_tf_LitBM = []
for i in TF_LitBM:
    j = matrix_tf.index(i)
    index_tf_LitBM.append(j)

# 99% = 48.79x
# 99.5% = 51.33
# 99.9% = 68.83

identity_tf = {}

## Calculate the most similar TFs for each TF in LitBM
for i in index_tf_LitBM:
    for j in range(len(matrix_distances[i])):
        if matrix_distances[i][j] == 'nan':
            continue
        elif float(matrix_distances[i][j]) >= 68.83 and matrix_tf[j] in TF_LitBM and matrix_tf[j] != matrix_tf[i]:
            if matrix_tf[i] not in identity_tf:
                identity_tf[matrix_tf[i]] = [matrix_tf[j]]
            else:
                identity_tf[matrix_tf[i]] += [matrix_tf[j]]


total_interactions= []
for TF1 in LitBM_dict.keys(): # For each TF in LitBM
    for TF2 in LitBM_dict[TF1]: # For each list of reported interactors of such TF in LitBM
        if TF1 in identity_tf and TF2 in identity_tf:
            first_tf = identity_tf[TF1][:]
            first_tf.append(TF1)
            second_tf = identity_tf[TF2][:]
            second_tf.append(TF2)
            new_interactions = [i for i in itertools.product(first_tf,second_tf)]
        elif TF1 in identity_tf:
            first_tf = identity_tf[TF1][:]
            first_tf.append(TF1)
            second_tf = [TF2]
            new_interactions = [i for i in itertools.product(first_tf, second_tf)]
        elif TF2 in identity_tf:
            first_tf = [TF1]
            second_tf = identity_tf[TF2][:]
            second_tf.append(TF2)
            new_interactions = [i for i in itertools.product(first_tf, second_tf)]
        try:
            total_interactions += new_interactions
        except:
            continue


print("Second Approach")

print("Number of total interactions", len(total_interactions))

f_total_interactions = []
for i in total_interactions:
    if f_total_interactions:
        if (i[0],i[1]) in f_total_interactions or (i[1],i[0]) in f_total_interactions:
            continue
        else:
            f_total_interactions.append(i)
    else:
        f_total_interactions.append(i)

print("Number of unique interactions", len(f_total_interactions))

new_intx = []
for pair in f_total_interactions:
    if pair[0] in LitBM_dict and pair[1] in LitBM_dict[pair[0]]:
        continue
        #print("%s and %s are ready in LitBM" % (pair[0],pair[1]))
    else:
        #print("%s and %s are new pairs" % (pair[0], pair[1]))
        new_intx.append((pair[0], pair[1]))
        
print("Number of unique interactions which are not in LitBM database", len(new_intx)) # 2173

with open("Second_approach.txt", "w") as f1:
    for pair in new_intx:
        tf_1, tf_2 = pair[0], pair[1]
        f1.write(tf_1 + "\t" + tf_2 + "\n")
# Out:
# Second Approach
# Number of total interactions 1997
# Number of unique interactions 338
# Number of unique interactions which are not in LitBM database 192
